# %%
import pandas as pd
import networkx as nx
import json

# %%
data = pd.read_csv("../data/graph.csv")

# %%
data
# Out:
#           main_artist                      id            name  popularity  \
# 0          Kanye West  6DPYiyq5kWVQS4RGwxzPC7           JAY-Z          81
# 1               JAY-Z  3Mcii5XWf6E0lrY3Uky4cA        Kid Cudi          77
# 2            Kid Cudi  1Oa0bMld0A3u5OTYfMzp5h  Kendrick Lamar          86
# 3      Kendrick Lamar  7B4hKK0S9QYnaoqa9OuwgX      A$AP Rocky          79
# 4          A$AP Rocky  4EnEZVjo3w1cwcQYePccay       Baby Keem          75
# ..                ...                     ...             ...         ...
# 77            Dr. Dre  2XnnxQzxFZG8qEPjakokPM           JAY-Z          81
# 78           Makaveli  1P8IfcNKwrkQP5xJWuhaOC           Migos          74
# 79             Redman  2Xu7q46Hf02xOoEIm4E1Qs             JID          73
# 80  Ol' Dirty Bastard  6DPYiyq5kWVQS4RGwxzPC7       A$AP Ferg          68
# 81  Naughty By Nature  6evKD5JWJON3qPBJtUEmtY        A$AP Mob          55
#
#                                                genres  \
# 0   ['east coast hip hop', 'gangster rap', 'hip ho...
# 1       ['hip hop', 'ohio hip hop', 'pop rap', 'rap']
# 2   ['conscious hip hop', 'hip hop', 'rap', 'west ...
# 3    ['east coast hip hop', 'hip hop', 'rap', 'trap']
# 4                                  ['hip hop', 'rap']
# ..                                                ...
# 77  ['east coast hip hop', 'gangster rap', 'hip ho...
# 78  ['atl hip hop', 'hip hop', 'pop rap', 'rap', '...
# 79  ['hip hop', 'pop rap', 'rap', 'underground hip...
# 80  ['hip hop', 'pop rap', 'rap', 'southern hip ho...
# 81     ['hip hop', 'rap', 'southern hip hop', 'trap']
#
#                                             relations
# 0   [{'id': '3nFkdlSjzX9mRTtwJOzDYB', 'name': 'JAY...
# 1   [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas...
# 2   [{'id': '2hPgGN4uhvXAxiXQBIXOmE', 'name': 'KID...
# 3   [{'id': '13ubrt8QOOCPljQ2FL1Kca', 'name': 'A$A...
# 4   [{'id': '5dHt1vcEm9qb8fCyLcB3HL', 'name': 'A$A...
# ..                                                ...
# 77  [{'id': '7B4hKK0S9QYnaoqa9OuwgX', 'name': 'Eaz...
# 78  [{'id': '76fO70b6BK2xt3UVOe4BIZ', 'name': 'Thu...
# 79  [{'id': '4VmEWwd8y9MCLwexFMdpwt', 'name': 'Met...
# 80  [{'id': '4iCwCMnqsNZ6atvRiADgtn', 'name': 'RZA...
# 81  [{'id': '7mldB9nEb6VC2cUj7EcgFw', 'name': "Kid...
#
# [82 rows x 6 columns]

# %%
G = nx.DiGraph()

# %%
for _, row in data.iterrows():
    main_artist = row["main_artist"]
    main_artist_genres = eval(row["genres"])
    conjunto1 = set(main_artist_genres)
    relations = eval(row["relations"])
    
    G.add_node(main_artist)
    
    for relation in relations:
        artist_relation = relation["name"] 
        artist_genres = relation["genres"].split(", ")
        conjunto2 = set(artist_genres) 
        
        weight = len(conjunto1.intersection(conjunto2)) + 1
        
        G.add_edge(main_artist, artist_relation, weight=weight)

# %%
nx.write_gml(G, "../resources/gephi/graph.gml")
