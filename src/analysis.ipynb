# %%
import pandas as pd
import csv

# %%
# pd.reset_option('display.max_rows')

data_rap = pd.read_csv("../data/rappers.csv")
data_pop = pd.read_csv("../data/pop_artist.csv")

# %%
data_pop
# Out:
#            main_artist                      id              name  popularity  \
# 0      Michael Jackson  1zuJe6b1roixEKMOtyrEak      The Jacksons          55
# 1         The Jacksons  51l0uqRxGaczYr4271pVIC            Prince          68
# 2               Prince  2mG8HHQ9S9kcbjcrb5N1FE             Wham!          68
# 3                Wham!  3sc7iUG1Wwpwx7bHeZolgx     Janet Jackson          62
# 4        Janet Jackson  7xkAwz0bQTGDSbkofyQt3U    George Michael          70
# ...                ...                     ...               ...         ...
# 1084    Sebastian Bach  7xkAwz0bQTGDSbkofyQt3U      Alison Moyet          45
# 1085           Mr. Big  2aS6jYh7ysTL1ZUsHneNgM    Spandau Ballet          58
# 1086     Richie Kotzen  1yMYjh77WgOVafRkI50mim  The Human League          59
# 1087  Nuno Bettencourt  4C3uGP8vRDzxrhJxZiOjTe         Kim Wilde          54
# 1088    Keith Richards  43mhFhQ4JAknA7Ik1bOZuV    The Communards          47
#
# ...

# %%
data_rap
# Out:
#          main_artist                      id              name  popularity  \
# 0         Kanye West  6DPYiyq5kWVQS4RGwxzPC7             JAY-Z          81
# 1              JAY-Z  3Mcii5XWf6E0lrY3Uky4cA          Kid Cudi          77
# 2           Kid Cudi  1Oa0bMld0A3u5OTYfMzp5h    Kendrick Lamar          86
# 3     Kendrick Lamar  7B4hKK0S9QYnaoqa9OuwgX        A$AP Rocky          79
# 4         A$AP Rocky  4EnEZVjo3w1cwcQYePccay         Baby Keem          75
# ...              ...                     ...               ...         ...
# 1045  Chamillionaire  5IcR3N7QB1j6KBL8eImZ8m        Gang Starr          61
# 1046     Trick Daddy  68kEuyFKyqrdQQLLsmiatm  Ghostface Killah          63
# 1047        Mystikal  2hPgGN4uhvXAxiXQBIXOmE        Method Man          67
# 1048    David Banner  5Matrg5du62bXwer29cU5T            Common          58
# 1049  Jermaine Dupri  0TkqXdyWLsssJH7okthMPQ            Redman          61
#
#                                                  genres
# ...
