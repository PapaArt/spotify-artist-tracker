# %%
import pandas as pd

# %%
data = pd.read_csv("../data/teste.csv")

# %%
data
# Out:
#            main_artist                      id                name  \
# 0           Kanye West  20qISvAhX20dpIbOOzGK3q               JAY-Z
# 1                JAY-Z  0ONHkAv9pCAFxb0zJwDNTy            Kid Cudi
# 2             Kid Cudi  4OBJLual30L7gRl5UkeRcT      Kendrick Lamar
# 3       Kendrick Lamar  1sBkRIssrMs1AbVkOJbc7a          A$AP Rocky
# 4           A$AP Rocky  59wfkuBoNyhDMQGCljbUbA           Baby Keem
# 5            Baby Keem  5me0Irg2ANcsgc93uaYrpb  Tyler, The Creator
# 6   Tyler, The Creator  55Aa2cqylxrFIXC767Z865         Frank Ocean
# 7          Frank Ocean  3ipn9JLAPI5GUEo4y4jcoi       Playboi Carti
# 8        Playboi Carti  1YfEcTuGvBQ8xSD1f53UnK             J. Cole
# 9              J. Cole  3ScY9CQxNLQei8Umvpx5g6    Childish Gambino
# 10    Childish Gambino  5K4W6rqBFWDnAN6FQUkS6x           21 Savage
# 11           21 Savage  01QTIT5P1pFP3QnnFSdsJf        Metro Boomin
# 12        Metro Boomin  1G9G7WwrXka3Z1r7aIDjI7         Joey Bada$$
# ...
