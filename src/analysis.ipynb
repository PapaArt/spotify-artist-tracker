# %%
import pandas as pd
import csv

# %%
# pd.reset_option('display.max_rows')

data_rap = pd.read_csv("../data/rap_world.csv")
data_pop = pd.read_csv("../data/pop_world.csv")
two_worlds = pd.concat([data_rap, data_pop], ignore_index=True)

# %%
two_worlds.to_csv('../data/two_worlds.csv', index=False)

# %%
two_worlds
# Out:
#                             main_artist                      id  \
# 0                            Kanye West  4yBK75WVCQXej1p04GWqxH
# 1                                 JAY-Z  35sCXuy5gN6Or69rZ9vqBs
# 2                                   Nas  31HjiqargV4NAw4GZqUale
# 3                               Pusha T  17lzZA2AlOHwCwFALHttmp
# 4                                  T.I.  20sxb77xiYeusSH8cVdatc
# ...                                 ...                     ...
# 4203                             Boston  6JL8zeS1NmiOftqZTRgdTz
# 4204              Huey Lewis & The News  7gAppWoH7pcYmphCVTXkzs
# 4205                               Styx  4nDoRrQiYLoBzwC5BhVJzF
# 4206                The Doobie Brothers  6S2OmqARrzebs0tKUEyXyp
# 4207  George Thorogood & The Destroyers  6dJeKm76NjfXBNTpHmOhfO
#
#                      name  popularity  \
# 0                   JAY-Z          81
# 1                Kid Cudi          77
# 2          Kendrick Lamar          86
# 3              A$AP Rocky          79
# 4               Baby Keem          75
# ...                   ...         ...
# 4203           Steve Lacy          79
# 4204             The 1975          74
# 4205  Megan Thee Stallion          75
# 4206              Cardi B          77
# 4207           Kali Uchis          81
#
#                                                  genres  \
# 0     ['east coast hip hop', 'gangster rap', 'hip ho...
# 1         ['hip hop', 'ohio hip hop', 'pop rap', 'rap']
# 2     ['conscious hip hop', 'hip hop', 'rap', 'west ...
# 3      ['east coast hip hop', 'hip hop', 'rap', 'trap']
# 4                                    ['hip hop', 'rap']
# ...                                                 ...
# 4203                                   ['afrofuturism']
# 4204  ['modern alternative rock', 'modern rock', 'po...
# 4205  ['houston rap', 'pop', 'r&b', 'rap', 'trap que...
# 4206                                     ['pop', 'rap']
# 4207                                  ['colombian pop']
#
#                                               relations
# 0     [{'id': '3nFkdlSjzX9mRTtwJOzDYB', 'name': 'JAY...
# 1     [{'id': '20qISvAhX20dpIbOOzGK3q', 'name': 'Nas...
# 2     [{'id': '6O2zJ0tId7g07yzHtX0yap', 'name': 'Mob...
# 3     [{'id': '2J257euzcjnDLipsyJH3F2', 'name': 'Cli...
# 4     [{'id': '3ipn9JLAPI5GUEo4y4jcoi', 'name': 'Lud...
# ...                                                 ...
# 4203  [{'id': '4salDzkGmfycRqNUbyBphh', 'name': 'Sty...
# 4204  [{'id': '6IFXsrXBpwbIqtOUOiAa3p', 'name': 'Ric...
# 4205  [{'id': '2hl0xAkS2AIRAu23TVMBG1', 'name': 'Kan...
# 4206  [{'id': '4FAEZeJcsYYBkNq2D3KGTV', 'name': 'Thr...
# 4207  [{'id': '1avbhJvMxjF2VhG7BXXn60', 'name': 'Geo...
#
# [4208 rows x 6 columns]
